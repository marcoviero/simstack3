# %%
# Standard modules
import pdb
import os
import sys
import json
import time
import logging
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

sys.path.append('..')
from simstackwrapper import SimstackWrapper
from simstackresults import SimstackResults

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:98% !important; }</style>"))
# Out:
# <style>.container { width:98% !important; }</style>

# %%
path_ini_file = os.path.join("..","config","example.ini")
simstack_object = SimstackWrapper(path_ini_file, read_maps=True, read_catalog=True, stack_automatically=True)
# Out:
# Simultaneously Stacking 78 Layers in spire_plw
# pickling to D:\pickles\simstack\stacked_flux_densities\uVista_DR2_example\uVista_DR2_example.pkl
# saved to  D:\pickles\simstack\stacked_flux_densities\uVista_DR2_example\uVista_DR2_example.pkl

# %%
# Pass simstack_object into SimstackResults to transform raw data into plots
simstack_object = SimstackResults(simstack_object)
simstack_object.parse_results()
# Out:
# Skipping SED estimates because only single wavelength measured.

# %%
simstack_object.plot_seds()
# Out:
# Skipping SED plotting because only single wavelength measured.

# %%
simstack_object.plot_flux_densities()
